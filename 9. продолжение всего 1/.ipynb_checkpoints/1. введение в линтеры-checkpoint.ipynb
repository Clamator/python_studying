# %% [markdown]
# качество кода:
#     читабельность
#     простота поддержки
#
# из негатиеых моментов: могут вылезти баги и ригидность(сложность расширения ПО)
#
#
# РЕР - это набор инструментов, регламентирующий процесс написания кода
# РЕР8 - описывает стили кодирования (какие отступы, как правильно именовать аргументы, как испортировать модули)
# РЕР20 - дзен языка пайтон (содержит главные мета принципы кодирования на питоне)

# %% [raw]
# проверку этих предписаний можно и нужно автоматизировать
# есть такое понятие как линт - это какие-то стилистические косяки или потенциальные баги, из-за нелогичных условий, нелогичных передач аргументов
#
# а есть линтеры - это автоматизированные инструменты, которые проверяют код на отсутствие или наличие этих линтов

# %% [raw]
# самые популярные - это пайлинт и флейк8
# в пайчарм уже встроен
#
# настраиваются:
#     на бэкграунде во время набора кода
#     перед чек ин
#     как часть континьюс интегрейнш
#
#     чек ин - это когда мы в какой-нибудь гит или в другую систему проверки версий отправляем код, он проверяет, не появилось ли новых ошибок, иногда работает так, что проверяет только количетсво ошибок, а не их самих
